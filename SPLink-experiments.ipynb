# %%
from splink import DuckDBAPI, Linker, SettingsCreator, block_on, splink_datasets
from arfpy import arf
import numpy as np
import pandas as pds
from matplotlib import pyplot as plt
import xgboost as xgb
from sklearn.metrics import accuracy_score, roc_auc_score
from splink import DuckDBAPI, block_on
from splink.blocking_analysis import (
    cumulative_comparisons_to_be_scored_from_blocking_rules_chart,
)
import splink.comparison_level_library as cll
import splink.comparison_library as cl
import gc
import math

# %%
def one_round(list_params_key, linkage, nA, nB, overlap, save_df, setting_info, dedup=False):

    df_origin = pds.DataFrame(np.array([np.round(np.random.normal(size=nA)*list_params[list_params_key][0]+50,0),
                            np.round(np.random.beta(0.2, 0.2, size=nA)*list_params[list_params_key][1]+1,0),
                            np.random.randint(0, list_params[list_params_key][2], size=nA)+1,
                            np.random.randint(0, list_params[list_params_key][3], size=nA)+1,
                            np.round(np.random.beta(1, 2, size=nA)*list_params[list_params_key][4]+1,0)]).transpose())
    
    df_destination = pds.DataFrame(np.array([np.round(np.random.normal(size=nB)*list_params[list_params_key][0]+50,0),
                                np.round(np.random.beta(0.2, 0.2, size=nB)*list_params[list_params_key][1]+1,0),
                                np.random.randint(0, list_params[list_params_key][2], size=nB)+1,
                                np.random.randint(0, list_params[list_params_key][3], size=nB)+1,
                                np.round(np.random.beta(1, 2, size=nB)*list_params[list_params_key][4]+1,0)]).transpose())
            
    df_origin.loc[:,"link"] = False
    df_destination.loc[:,"link"] = False

    # "at_random", "strong_dep_pivs", "light_dep_pivs"

    if linkage == "strong_dep_pivs":

        # selection on piv
        df_origin.loc[ (df_origin[2]) > (df_origin[2]).quantile(1-overlap),"link"] = True
    
        df_origin.loc[ df_origin.link, 0 ] = np.round(np.random.normal(size=df_origin.link.sum())*(list_params[list_params_key][0]), 0)
        df_origin.loc[ df_origin.link, 2 ] = np.random.randint(list_params[list_params_key][2], 2* list_params[list_params_key][2], size=df_origin.link.sum())+1
        df_origin.loc[ df_origin.link, 4 ] = np.round(np.random.beta(2, 1, size=df_origin.link.sum())*list_params[list_params_key][4], 0)

    elif linkage == "light_dep_pivs":

        # selection on piv
        df_origin.loc[ (df_origin[2]) > (df_origin[2]).quantile(1-overlap),"link"] = True
    
        # df_origin.loc[ df_origin.link, 0 ] = np.round(np.random.normal(size=df_origin.link.sum())*list_params[list_params_key][0]+45, 0)
        # # df_origin.loc[ df_origin.link, 2 ] = np.random.randint(0, 0.5*list_params[list_params_key][2], size=df_origin.link.sum())+1
        # df_origin.loc[ df_origin.link, 4 ] = np.round(np.random.beta(2, 1, size=df_origin.link.sum())*list_params[list_params_key][4], 0)

    elif linkage == "at_random":

        rng = np.random.default_rng()
        rdgen = rng.choice(df_origin.shape[0], size=int(overlap*df_origin.shape[0]), replace=False)
        df_origin.loc[rdgen,"link"] = True

    df_origin.loc[:,"unique_id"] = range(1,1+df_origin.shape[0])
    df_destination.loc[:,"unique_id"] = range(5000001,5000001+df_destination.shape[0])

    df_origin.loc[:,"synthetic"] = False
    df_destination.loc[:,"synthetic"] = False

    df_origin.columns = ["piv1", "piv2", "piv3", "piv4", "piv5", "link", "unique_id", "synthetic"]
    df_destination.columns = ["piv1", "piv2", "piv3", "piv4", "piv5", "link", "unique_id", "synthetic"]
        
    # links get identical in the other file:
    df_destination.iloc[np.where(df_origin.link)[0]] = df_origin.iloc[np.where(df_origin.link)[0]]

    df_origin.loc[:,"duplication"] = False
    df_destination.loc[:,"duplication"] = False
    
    if dedup:
        
        # we augment each file with 5% of its size with duplicated records
        # 2.5% of the links get duplicated (at random)
        # 2.5% of the non-links get duplicated (at random)
        
        rng = np.random.default_rng()
        rdgen = rng.choice(np.where(df_origin.link)[0], size=int(0.025*df_origin.shape[0]), replace=False)
        df_origin.loc[rdgen,"duplication"] = True
        rng = np.random.default_rng()
        rdgen = rng.choice(np.where(~df_origin.link)[0], size=int(0.025*df_origin.shape[0]), replace=False)
        df_origin.loc[rdgen,"duplication"] = True
        
        rng = np.random.default_rng()
        rdgen = rng.choice(np.where(df_destination.link)[0], size=int(0.025*df_destination.shape[0]), replace=False)
        df_destination.loc[rdgen,"duplication"] = True
        rng = np.random.default_rng()
        rdgen = rng.choice(np.where(~df_destination.link)[0], size=int(0.025*df_destination.shape[0]), replace=False)
        df_destination.loc[rdgen,"duplication"] = True

        # duplicate:
        new_set = df_origin.loc[df_origin.duplication,:].copy()
        df_origin = pds.concat([df_origin, new_set])
        new_set = df_destination.loc[df_destination.duplication,:].copy()
        df_destination = pds.concat([df_destination, new_set])

        nA = df_origin.shape[0]
        nB = df_destination.shape[0]

        df_origin = df_origin.reset_index(drop=True)
        df_destination = df_destination.reset_index(drop=True)

    for column in df_destination.columns:
        unique_values = df_destination[column].unique()
        print(f"Unique values in column '{column}': {len(unique_values)}")

    # info to save
    overlapInA = sum(df_origin.link)/df_origin.shape[0]
    overlapInB = sum(df_destination.link)/df_destination.shape[0]
    difficultyInA = len(np.unique(df_origin[["piv1", "piv2", "piv3", "piv4", "piv5"]].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)))/df_origin.shape[0]
    difficultyInB = len(np.unique(df_destination[["piv1", "piv2", "piv3", "piv4", "piv5"]].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)))/df_destination.shape[0]
    difficultyInL = len(np.unique(df_destination.loc[df_destination.link,["piv1", "piv2", "piv3", "piv4", "piv5"]].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)))/df_destination.link.sum()
    difficultyInNL = len(np.unique(df_destination.loc[~df_destination.link,["piv1", "piv2", "piv3", "piv4", "piv5"]].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)))/(df_destination.shape[0]-df_destination.link.sum())

    print(difficultyInB)
    max_id_ = max( max(df_destination.unique_id), max(df_origin.unique_id) )

    #
    # print("PIV1")
    # print("links profile")
    # plt.show(plt.hist(df_destination.loc[df_destination.link,"piv1"]))
    # print("PIV1")
    # print("non-links profile")
    # plt.show(plt.hist(df_destination.loc[~df_destination.link,"piv1"]))
    # print("PIV2")
    # print("links profile")
    # plt.show(plt.hist(df_destination.loc[df_destination.link,"piv2"]))
    # print("PIV2")
    # print("non-links profile")
    # plt.show(plt.hist(df_destination.loc[~df_destination.link,"piv2"]))
    # print("PIV3")
    # print("links profile")
    # plt.show(plt.hist(df_destination.loc[df_destination.link,"piv3"]))
    # print("PIV3")
    # print("non-links profile")
    # plt.show(plt.hist(df_destination.loc[~df_destination.link,"piv3"]))
    # print("PIV4")
    # print("links profile")
    # plt.show(plt.hist(df_destination.loc[df_destination.link,"piv4"]))
    # print("PIV4")
    # print("non-links profile")
    # plt.show(plt.hist(df_destination.loc[~df_destination.link,"piv4"]))
    # print("PIV5")
    # print("links profile")
    # plt.show(plt.hist(df_destination.loc[df_destination.link,"piv5"]))
    # print("PIV5")
    # print("non-links profile")
    # plt.show(plt.hist(df_destination.loc[~df_destination.link,"piv5"]))
    #

    # Train the ARF
    my_arf = arf.arf(x = df_destination[["piv1", "piv2", "piv3", "piv4", "piv5"]])
    
    # Get density estimates
    my_arf.forde()

    nS = round(0.10*df_destination.shape[0])
    
    # Generate data
    synthdata = my_arf.forge(n = nS)
    
    synthdata['unique_id'] = max_id_ + np.array(range(1,1+nS))
    synthdata['link'] = False
    synthdata['synthetic'] = True
    
    synthetictest = synthdata.copy()
    synthetictest[["piv1", "piv2", "piv3", "piv4", "piv5"]] = round(synthetictest[["piv1", "piv2", "piv3", "piv4", "piv5"]],0)
    
    # investigate links profiles / synthetic profiles
    
    Xtrain = pds.concat([ df_destination.loc[0:round(nB/2,0),["piv1", "piv2", "piv3", "piv4", "piv5"]], synthetictest.loc[0:round(nS/2,0),["piv1", "piv2", "piv3", "piv4", "piv5"]]  ])
    ytrain = pds.concat([ df_destination.loc[0:round(nB/2,0),["synthetic"]], synthetictest.loc[0:round(nS/2,0),["synthetic"]]  ])

    print(round(nB/2,0))
    print(df_destination.index)
        
    Xtest = pds.concat([ df_destination.loc[round(nB/2,0):nB,["piv1", "piv2", "piv3", "piv4", "piv5"]], synthetictest.loc[round(nS/2,0):nS,["piv1", "piv2", "piv3", "piv4", "piv5"]]  ])
    ytest = pds.concat([ df_destination.loc[round(nB/2,0):nB,["synthetic"]], synthetictest.loc[round(nS/2,0):nS,["synthetic"]]  ])

    # info to save
    ytrain_synth_prop = ytrain.sum()/ytrain.shape[0]
    ytest_synth_prop = ytest.sum()/ytest.shape[0]
    
    model = xgb.XGBClassifier()
    model.fit(Xtrain, ytrain)
    predictions = model.predict(Xtest)
    y_score = model.predict_proba(Xtest)[:, 1]
    auc = roc_auc_score(ytest, y_score)

    # info to save
    auc_synth = auc

    rng = np.random.default_rng()
    rdgen = rng.choice(np.where(df_destination.link)[0], size=sum(df_destination.link), replace=False)
    rng2 = np.random.default_rng()
    rdgen2 = rng.choice(np.where(~df_destination.link)[0], size=sum(~df_destination.link), replace=False)
    
    XtrainL1 = df_destination.loc[rdgen[0:int(len(rdgen)/2)],["piv1", "piv2", "piv3", "piv4", "piv5"]]
    XtrainL2 = df_destination.loc[rdgen2[0:int(len(rdgen2)/2)],["piv1", "piv2", "piv3", "piv4", "piv5"]]
    XtrainL = pds.concat([XtrainL1,XtrainL2])
    ytrainL1 = df_destination.loc[rdgen[0:int(len(rdgen)/2)],["link"]]
    ytrainL2 = df_destination.loc[rdgen2[0:int(len(rdgen2)/2)],["link"]]
    ytrainL = pds.concat([ytrainL1,ytrainL2])
    
    XtestL1 = df_destination.loc[rdgen[int(len(rdgen)/2):len(rdgen)],["piv1", "piv2", "piv3", "piv4", "piv5"]]
    XtestL2 = df_destination.loc[rdgen2[int(len(rdgen2)/2):len(rdgen2)],["piv1", "piv2", "piv3", "piv4", "piv5"]]
    XtestL = pds.concat([XtestL1,XtestL2])
    ytestL1 = df_destination.loc[rdgen[int(len(rdgen)/2):len(rdgen)],["link"]]
    ytestL2 = df_destination.loc[rdgen2[int(len(rdgen2)/2):len(rdgen2)],["link"]]
    ytestL = pds.concat([ytestL1,ytestL2])

    # info to save
    ytrain_link_prop = ytrainL.sum()/ytrainL.shape[0]
    ytest_link_prop = ytestL.sum()/ytestL.shape[0]
    
    model = xgb.XGBClassifier()
    model.fit(XtrainL, ytrainL)
    predictions = model.predict(XtestL)
    y_scoreL = model.predict_proba(XtestL)[:, 1]
    auc = roc_auc_score(ytestL, y_scoreL)

    # info to save
    auc_link = auc

    NEW_df_destination = pds.concat([df_destination, synthetictest])

    NEW_df_destination[["piv1", "piv2", "piv3", "piv4", "piv5"]] = NEW_df_destination[["piv1", "piv2", "piv3", "piv4", "piv5"]].astype(int)
    df_origin[["piv1", "piv2", "piv3", "piv4", "piv5"]] = df_origin[["piv1", "piv2", "piv3", "piv4", "piv5"]].astype(int)

    if save_df:

        NEW_df_destination.to_csv(f'{setting_info}_df_destination{_}.csv', index=False)
        df_origin.to_csv(f'{setting_info}_df_origin{_}.csv', index=False)
    
    blocking_rule_1 = """
    round(l.piv1) = round(r.piv1) and
    round(l.piv2) = round(r.piv2) and
    round(l.piv3) = round(r.piv3) and
    round(l.piv4) = round(r.piv4) and
    round(l.piv5) = round(r.piv5)
    """
    
    db_api = DuckDBAPI()
    
    brs = [
      blocking_rule_1,
    ]
    
    comparison_1 = {
      "output_column_name": "piv1",
      "comparison_levels": [
          cll.NullLevel("piv1"),
          cll.ExactMatchLevel("piv1"),
          cll.ElseLevel(),
      ],
      "comparison_description": "piv1 difference",
    }
    
    comparison_2 = {
      "output_column_name": "piv2",
      "comparison_levels": [
          cll.NullLevel("piv2"),
          cll.ExactMatchLevel("piv2"),
          cll.ElseLevel(),
      ],
      "comparison_description": "piv2 difference",
    }
    
    comparison_3 = {
      "output_column_name": "piv3",
      "comparison_levels": [
          cll.NullLevel("piv3"),
          cll.ExactMatchLevel("piv3"),
          cll.ElseLevel(),
      ],
      "comparison_description": "piv3 difference",
    }
    
    comparison_4 = {
      "output_column_name": "piv4",
      "comparison_levels": [
          cll.NullLevel("piv4"),
          cll.ExactMatchLevel("piv4"),
          cll.ElseLevel(),
      ],
      "comparison_description": "piv4 difference",
    }
    
    comparison_5 = {
      "output_column_name": "piv5",
      "comparison_levels": [
          cll.NullLevel("piv5"),
          cll.ExactMatchLevel("piv5"),
          cll.ElseLevel(),
      ],
      "comparison_description": "piv5 difference",
    }
    
    settings = SettingsCreator(
      link_type="link_only",
      blocking_rules_to_generate_predictions=brs,
      comparisons=[
          comparison_1,
          comparison_2,
          comparison_3,
          comparison_4,
          comparison_5,
      ],
      retain_intermediate_calculation_columns=True,
    )
    
    linker = Linker(
      [df_origin, NEW_df_destination],
      settings,
      input_table_aliases=["__ori", "_dest"],
      db_api=db_api,
    )
    
    linker.training.estimate_u_using_random_sampling(max_pairs=1e7)
    
    # linker.training.estimate_parameters_using_expectation_maximisation(block_on("piv1"))
    # linker.training.estimate_parameters_using_expectation_maximisation(block_on("piv2"))
    # linker.training.estimate_parameters_using_expectation_maximisation(block_on("piv3"))
    # linker.training.estimate_parameters_using_expectation_maximisation(block_on("piv4"))
    # linker.training.estimate_parameters_using_expectation_maximisation(block_on("piv5"))
    linker.training.estimate_parameters_using_expectation_maximisation(block_on("piv1","piv2","piv3"))
    linker.training.estimate_parameters_using_expectation_maximisation(block_on("piv4","piv5"))
    
    df_predict = linker.inference.predict(threshold_match_probability=0.00001)

    # info to save
    max_proba_linked = max(df_predict.as_pandas_dataframe().match_probability)
    
    median_proba_linked = np.median(df_predict.as_pandas_dataframe().match_probability)
    median_proba_linked = math.floor(median_proba_linked * 100) / 100

    linkedpairs05 = df_predict.as_pandas_dataframe()

    # we cheat because the model sometimes does not link anything
    # if there are not enough linked pairs: threshold is set at median match_probability
    # if there are enough linked pairs: threshold is set at max(0.5, median match_probability) (this may help for 1-2-1 assignment constraint)
    # in general we cheat because we do not enforce 1-2-1 assignment constraint (it is not implemented in SPLink)
    if max_proba_linked >= 0.5:
        threshold_for_links = 0.5 # max(0.5, median_proba_linked)
    else:
        threshold_for_links = median_proba_linked
        
    linkedpairs05 = linkedpairs05.loc[linkedpairs05.match_probability>threshold_for_links,:]
    
    synthlinkedpairs = linkedpairs05[linkedpairs05.unique_id_r > max_id_]
    reallinkedpairs = linkedpairs05[linkedpairs05.unique_id_r <= max_id_]

    tp = 0
    fp = 0
    true_fdr = 0
    hat_fdr_us = 0
    hat_fdr_prob = 0

    if reallinkedpairs.shape[0]!=0 or synthlinkedpairs.shape[0]!=0:
    
        tp = (reallinkedpairs.unique_id_l == reallinkedpairs.unique_id_r).sum()
        fp = (reallinkedpairs.unique_id_l != reallinkedpairs.unique_id_r).sum()
        true_fdr = fp/(tp+fp)
        hat_fdr_us = ( synthlinkedpairs.shape[0] * (nB / nS) ) / reallinkedpairs.shape[0]
        hat_fdr_prob = 1 - reallinkedpairs[reallinkedpairs.match_probability>threshold_for_links].match_probability.sum() / reallinkedpairs[reallinkedpairs.match_probability>threshold_for_links].shape[0]
        
    # info to save
    synth_pairs_prop = synthlinkedpairs.shape[0] / nS
    real_pairs_prop = fp / nB
    
    return overlapInA, overlapInB, difficultyInA, difficultyInB, difficultyInL, difficultyInNL, ytrain_synth_prop, ytest_synth_prop, auc_synth, ytrain_link_prop, ytest_link_prop, auc_link, max_proba_linked, median_proba_linked, threshold_for_links, synth_pairs_prop, real_pairs_prop, true_fdr, hat_fdr_us, hat_fdr_prob

# %%
# STUDY SCALABILITY

linkagestructures = ["at_random"]
nAlist = [100000]
list_params = { 85:[10,16,10,15,14], 95:[10,20,15,25,20] }       
set_of_overlap = [0.35, 0.75]      

nB = 200000
save_df = False # True

# %%
# STUDY ROBUSTNESS TO LINKS HAPPEN AT RANDOM

linkagestructures = ["at_random", "strong_dep_pivs"] # "light_dep_pivs"
nAlist = [2002, 4502]
list_params = { 85:[1.5,7,7,8,8], 95:[2,9,9,10,10] } 
set_of_overlap = [0.35, 0.75]      

nB = 5000
save_df = False # True

# %%
# STUDY ROBUSTNESS TO THE PRESENCE OF NON-DEDUPLICATED DATA

linkagestructures = ["at_random"]
nAlist = [2002, 4502]
list_params = { 85:[10,16,10,15,14], 95:[10,20,15,25,20] }       
set_of_overlap = [0.35, 0.75]      

nB = 5000
save_df = False # True
# change the dedup parameter below in the code!!!

# %%
                          
dico_results_final = {}

for linkage in linkagestructures:
    
    dico_results_linkage = {}
    
    for nA in nAlist:
    
        dico_results_size = {}
        
        for list_params_key in list_params.keys():
            
            dico_results_setting = {}
            
            for overlap in set_of_overlap:
            
                print("OVERLAP")
                print(overlap)
        
                iter_secu = 0
            
                overlapInA_res = []
                overlapInB_res = []
                difficultyInA_res = []
                difficultyInB_res = []
                difficultyInL_res = []
                difficultyInNL_res = []
                ytrain_synth_prop_res = []
                ytest_synth_prop_res = []
                auc_synth_res = []
                ytrain_link_prop_res = []
                ytest_link_prop_res = []
                auc_link_res = []
                max_proba_linked_res = []
                median_proba_linked_res = []
                threshold_for_links_res = []
                synth_pairs_prop_res = []
                real_pairs_prop_res = []
                true_fdr_res = []
                hat_fdr_us_res = []
                hat_fdr_prob_res = []
        
                setting_info = f"links_{linkage}_nA_{nA}_discrlevel_{list_params_key}_overlaplevel_{overlap}_highdim"   
            
                while len(np.nonzero(true_fdr_res)[0]) < 10 and iter_secu < 15:
        
                    iter_secu += 1
            
                    print("ITERATION")
                    print(iter_secu)
        
                    overlapInA, overlapInB, difficultyInA, difficultyInB, difficultyInL, difficultyInNL, ytrain_synth_prop, ytest_synth_prop, auc_synth, ytrain_link_prop, ytest_link_prop, auc_link, max_proba_linked, median_proba_linked, threshold_for_links, synth_pairs_prop, real_pairs_prop, true_fdr, hat_fdr_us, hat_fdr_prob = one_round(list_params_key, linkage, nA, nB, overlap, save_df, setting_info)   # # #   
        
                    overlapInA_res.append(overlapInA)
                    overlapInB_res.append(overlapInB)
                    difficultyInA_res.append(difficultyInA)
                    difficultyInB_res.append(difficultyInB)
                    difficultyInL_res.append(difficultyInL)
                    difficultyInNL_res.append(difficultyInNL)
                    ytrain_synth_prop_res.append(ytrain_synth_prop)
                    ytest_synth_prop_res.append(ytest_synth_prop)
                    auc_synth_res.append(auc_synth)
                    ytrain_link_prop_res.append(ytrain_link_prop)
                    ytest_link_prop_res.append(ytest_link_prop)
                    auc_link_res.append(auc_link)
                    max_proba_linked_res.append(max_proba_linked)
                    median_proba_linked_res.append(median_proba_linked)
                    threshold_for_links_res.append(threshold_for_links)
                    synth_pairs_prop_res.append(synth_pairs_prop)
                    real_pairs_prop_res.append(real_pairs_prop)
                    true_fdr_res.append(true_fdr)
                    hat_fdr_us_res.append(hat_fdr_us)
                    hat_fdr_prob_res.append(hat_fdr_prob)
                
                    dico_results_setting[overlap] = {
                        
                        "overlapInA" : overlapInA_res,
                        "overlapInB" : overlapInB_res,
                        "difficultyInA" : difficultyInA_res,
                        "difficultyInB" : difficultyInB_res,
                        "difficultyInL" : difficultyInL_res,
                        "difficultyInNL" : difficultyInNL_res,
                        "ytrain_synth_prop" : ytrain_synth_prop_res,
                        "ytest_synth_prop" : ytest_synth_prop_res,
                        "auc_synth" : auc_synth_res,
                        "ytrain_link_prop" : ytrain_link_prop_res,
                        "ytest_link_prop" : ytest_link_prop_res,
                        "auc_link" : auc_link_res,
                        "max_proba_linked" : max_proba_linked_res,
                        "median_proba_linked" : median_proba_linked_res,
                        "threshold_for_links" : threshold_for_links_res,
                        "synth_pairs_prop" : synth_pairs_prop_res,
                        "real_pairs_prop" : real_pairs_prop_res,
                        "true_fdr" : true_fdr_res,
                        "hat_fdr_us" : hat_fdr_us_res,
                        "hat_fdr_prob" : hat_fdr_prob_res
                        
                    }
        
                    print(nA)
                    print(list_params_key)
                    print(overlap)
                    print(dico_results_setting)
                
                    gc.collect()
        
            dico_results_size[list_params_key] = dico_results_setting
        
        dico_results_linkage[nA] = dico_results_size
    
    dico_results_final[linkage] = dico_results_linkage
# Out:
# OVERLAP
# 0.35
# ITERATION
# 1
# Unique values in column 'piv1': 11
# Unique values in column 'piv2': 8
# Unique values in column 'piv3': 7
# Unique values in column 'piv4': 8
# Unique values in column 'piv5': 9
# Unique values in column 'link': 2
# Unique values in column 'unique_id': 5000
# Unique values in column 'synthetic': 1
# Unique values in column 'duplication': 1
# 0.7932
# Initial accuracy is 0.4904
# /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/arfpy/arf.py:329: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.factor_cols[j]:
# 2500.0
# RangeIndex(start=0, stop=5000, step=1)
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - piv1 (no m values are trained).
#     - piv2 (no m values are trained).
#     - piv3 (no m values are trained).
#     - piv4 (no m values are trained).
#     - piv5 (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."piv1" = r."piv1") AND (l."piv2" = r."piv2") AND (l."piv3" = r."piv3")
#
# Parameter estimates will be made for the following comparison(s):
#     - piv4
#     - piv5
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - piv1
#     - piv2
#     - piv3
#
# Iteration 1: Largest change in params was -0.00432 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 2: Largest change in params was 0.00281 in the m_probability of piv5, level `All other comparisons`
# Iteration 3: Largest change in params was 0.00185 in the m_probability of piv5, level `All other comparisons`
# Iteration 4: Largest change in params was -0.00123 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 5: Largest change in params was 0.000831 in the m_probability of piv5, level `All other comparisons`
# Iteration 6: Largest change in params was 0.000762 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 7: Largest change in params was -0.000892 in the m_probability of piv4, level `All other comparisons`
# Iteration 8: Largest change in params was 0.000965 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 9: Largest change in params was 0.001 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 10: Largest change in params was -0.00101 in the m_probability of piv4, level `All other comparisons`
# Iteration 11: Largest change in params was -0.00101 in the m_probability of piv4, level `All other comparisons`
# Iteration 12: Largest change in params was -0.00101 in the m_probability of piv4, level `All other comparisons`
# Iteration 13: Largest change in params was 0.000992 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 14: Largest change in params was -0.000975 in the m_probability of piv4, level `All other comparisons`
# Iteration 15: Largest change in params was 0.000956 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 16: Largest change in params was 0.000936 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 17: Largest change in params was -0.000916 in the m_probability of piv4, level `All other comparisons`
# Iteration 18: Largest change in params was -0.000896 in the m_probability of piv4, level `All other comparisons`
# Iteration 19: Largest change in params was 0.000876 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 20: Largest change in params was -0.000856 in the m_probability of piv4, level `All other comparisons`
# Iteration 21: Largest change in params was 0.000837 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 22: Largest change in params was -0.000818 in the m_probability of piv4, level `All other comparisons`
# Iteration 23: Largest change in params was -0.000799 in the m_probability of piv4, level `All other comparisons`
# Iteration 24: Largest change in params was 0.000781 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 25: Largest change in params was 0.000764 in the m_probability of piv4, level `Exact match on piv4`
#
# EM converged after 25 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - piv1 (no m values are trained).
#     - piv2 (no m values are trained).
#     - piv3 (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."piv4" = r."piv4") AND (l."piv5" = r."piv5")
#
# Parameter estimates will be made for the following comparison(s):
#     - piv1
#     - piv2
#     - piv3
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - piv4
#     - piv5
#
# Iteration 1: Largest change in params was 0.00412 in the m_probability of piv3, level `All other comparisons`
# Iteration 2: Largest change in params was -0.00275 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 3: Largest change in params was -0.00189 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 4: Largest change in params was 0.00134 in the m_probability of piv3, level `All other comparisons`
# Iteration 5: Largest change in params was -0.000988 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 6: Largest change in params was -0.000766 in the m_probability of piv2, level `All other comparisons`
# Iteration 7: Largest change in params was -0.000872 in the m_probability of piv2, level `All other comparisons`
# Iteration 8: Largest change in params was 0.000928 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 9: Largest change in params was 0.000953 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 10: Largest change in params was -0.00096 in the m_probability of piv2, level `All other comparisons`
# Iteration 11: Largest change in params was -0.000955 in the m_probability of piv2, level `All other comparisons`
# Iteration 12: Largest change in params was -0.000943 in the m_probability of piv2, level `All other comparisons`
# Iteration 13: Largest change in params was -0.000927 in the m_probability of piv2, level `All other comparisons`
# Iteration 14: Largest change in params was 0.000908 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 15: Largest change in params was 0.000888 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 16: Largest change in params was -0.000868 in the m_probability of piv2, level `All other comparisons`
# Iteration 17: Largest change in params was 0.000848 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 18: Largest change in params was -0.000828 in the m_probability of piv2, level `All other comparisons`
# Iteration 19: Largest change in params was 0.000809 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 20: Largest change in params was 0.000789 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 21: Largest change in params was -0.000771 in the m_probability of piv2, level `All other comparisons`
# Iteration 22: Largest change in params was 0.000752 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 23: Largest change in params was -0.000735 in the m_probability of piv2, level `All other comparisons`
# Iteration 24: Largest change in params was 0.000718 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 25: Largest change in params was -0.000701 in the m_probability of piv2, level `All other comparisons`
#
# EM converged after 25 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values
# Blocking time: 0.01 seconds
# Predict time: 0.05 seconds
# 2002
# 85
# 0.35
# {0.35: {'overlapInA': [0.34965034965034963], 'overlapInB': [0.14], 'difficultyInA': [0.8921078921078921], 'difficultyInB': [0.7932], 'difficultyInL': [np.float64(0.9542857142857143)], 'difficultyInNL': [np.float64(0.8181395348837209)], 'ytrain_synth_prop': [synthetic    0.091206
# dtype: float64], 'ytest_synth_prop': [synthetic    0.090909
# dtype: float64], 'auc_synth': [np.float64(0.4827088)], 'ytrain_link_prop': [link    0.14
# dtype: float64], 'ytest_link_prop': [link    0.14
# dtype: float64], 'auc_link': [np.float64(0.49102591362126247)], 'max_proba_linked': [0.41406256855084755], 'median_proba_linked': [0.41], 'threshold_for_links': [0.41], 'synth_pairs_prop': [0.212], 'real_pairs_prop': [np.float64(0.2148)], 'true_fdr': [np.float64(0.6054114994363021)], 'hat_fdr_us': [0.5975197294250282], 'hat_fdr_prob': [np.float64(0.5859374314491524)]}}
# ITERATION
# 2
# Unique values in column 'piv1': 12
# Unique values in column 'piv2': 8
# Unique values in column 'piv3': 7
# Unique values in column 'piv4': 8
# Unique values in column 'piv5': 9
# Unique values in column 'link': 2
# Unique values in column 'unique_id': 5000
# Unique values in column 'synthetic': 1
# Unique values in column 'duplication': 1
# 0.7902
# Initial accuracy is 0.4912
# /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/arfpy/arf.py:329: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.factor_cols[j]:
# 2500.0
# RangeIndex(start=0, stop=5000, step=1)
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - piv1 (no m values are trained).
#     - piv2 (no m values are trained).
#     - piv3 (no m values are trained).
#     - piv4 (no m values are trained).
#     - piv5 (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."piv1" = r."piv1") AND (l."piv2" = r."piv2") AND (l."piv3" = r."piv3")
#
# Parameter estimates will be made for the following comparison(s):
#     - piv4
#     - piv5
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - piv1
#     - piv2
#     - piv3
#
# Iteration 1: Largest change in params was -0.00192 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 2: Largest change in params was 0.00116 in the m_probability of piv5, level `All other comparisons`
# Iteration 3: Largest change in params was -0.000693 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 4: Largest change in params was 0.0004 in the m_probability of piv5, level `All other comparisons`
# Iteration 5: Largest change in params was -0.000217 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 6: Largest change in params was 0.000304 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 7: Largest change in params was 0.000368 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 8: Largest change in params was -0.000406 in the m_probability of piv4, level `All other comparisons`
# Iteration 9: Largest change in params was 0.000427 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 10: Largest change in params was -0.000439 in the m_probability of piv4, level `All other comparisons`
# Iteration 11: Largest change in params was -0.000443 in the m_probability of piv4, level `All other comparisons`
# Iteration 12: Largest change in params was 0.000444 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 13: Largest change in params was -0.000443 in the m_probability of piv4, level `All other comparisons`
# Iteration 14: Largest change in params was -0.00044 in the m_probability of piv4, level `All other comparisons`
# Iteration 15: Largest change in params was 0.000436 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 16: Largest change in params was -0.000432 in the m_probability of piv4, level `All other comparisons`
# Iteration 17: Largest change in params was 0.000428 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 18: Largest change in params was 0.000423 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 19: Largest change in params was 0.000418 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 20: Largest change in params was -0.000414 in the m_probability of piv4, level `All other comparisons`
# Iteration 21: Largest change in params was -0.000409 in the m_probability of piv4, level `All other comparisons`
# Iteration 22: Largest change in params was 0.000404 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 23: Largest change in params was -0.0004 in the m_probability of piv4, level `All other comparisons`
# Iteration 24: Largest change in params was 0.000395 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 25: Largest change in params was -0.000391 in the m_probability of piv4, level `All other comparisons`
#
# EM converged after 25 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - piv1 (no m values are trained).
#     - piv2 (no m values are trained).
#     - piv3 (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."piv4" = r."piv4") AND (l."piv5" = r."piv5")
#
# Parameter estimates will be made for the following comparison(s):
#     - piv1
#     - piv2
#     - piv3
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - piv4
#     - piv5
#
# Iteration 1: Largest change in params was 0.00334 in the m_probability of piv2, level `All other comparisons`
# Iteration 2: Largest change in params was -0.00252 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 3: Largest change in params was 0.00201 in the m_probability of piv2, level `All other comparisons`
# Iteration 4: Largest change in params was -0.00168 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 5: Largest change in params was 0.00148 in the m_probability of piv2, level `All other comparisons`
# Iteration 6: Largest change in params was -0.00135 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 7: Largest change in params was 0.00127 in the m_probability of piv2, level `All other comparisons`
# Iteration 8: Largest change in params was 0.00122 in the m_probability of piv2, level `All other comparisons`
# Iteration 9: Largest change in params was 0.00119 in the m_probability of piv2, level `All other comparisons`
# Iteration 10: Largest change in params was -0.00118 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 11: Largest change in params was -0.00117 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 12: Largest change in params was 0.00116 in the m_probability of piv2, level `All other comparisons`
# Iteration 13: Largest change in params was -0.00116 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 14: Largest change in params was 0.00116 in the m_probability of piv2, level `All other comparisons`
# Iteration 15: Largest change in params was -0.00116 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 16: Largest change in params was -0.00116 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 17: Largest change in params was -0.00116 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 18: Largest change in params was 0.00116 in the m_probability of piv2, level `All other comparisons`
# Iteration 19: Largest change in params was 0.00116 in the m_probability of piv2, level `All other comparisons`
# Iteration 20: Largest change in params was 0.00116 in the m_probability of piv2, level `All other comparisons`
# Iteration 21: Largest change in params was -0.00116 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 22: Largest change in params was 0.00116 in the m_probability of piv2, level `All other comparisons`
# Iteration 23: Largest change in params was -0.00116 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 24: Largest change in params was -0.00116 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 25: Largest change in params was 0.00115 in the m_probability of piv2, level `All other comparisons`
#
# EM converged after 25 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values
# Blocking time: 0.01 seconds
# Predict time: 0.05 seconds
# 2002
# 85
# 0.35
# {0.35: {'overlapInA': [0.34965034965034963, 0.34965034965034963], 'overlapInB': [0.14, 0.14], 'difficultyInA': [0.8921078921078921, 0.9000999000999002], 'difficultyInB': [0.7932, 0.7902], 'difficultyInL': [np.float64(0.9542857142857143), np.float64(0.9585714285714285)], 'difficultyInNL': [np.float64(0.8181395348837209), np.float64(0.8137209302325581)], 'ytrain_synth_prop': [synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64], 'ytest_synth_prop': [synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64], 'auc_synth': [np.float64(0.4827088), np.float64(0.5224783999999999)], 'ytrain_link_prop': [link    0.14
# dtype: float64, link    0.14
# dtype: float64], 'ytest_link_prop': [link    0.14
# dtype: float64, link    0.14
# dtype: float64], 'auc_link': [np.float64(0.49102591362126247), np.float64(0.5131189368770764)], 'max_proba_linked': [0.41406256855084755, 0.39850141654742727], 'median_proba_linked': [0.41, 0.39], 'threshold_for_links': [0.41, 0.39], 'synth_pairs_prop': [0.212, 0.214], 'real_pairs_prop': [np.float64(0.2148), np.float64(0.2348)], 'true_fdr': [np.float64(0.6054114994363021), np.float64(0.6264674493062967)], 'hat_fdr_us': [0.5975197294250282, 0.5709711846318036], 'hat_fdr_prob': [np.float64(0.5859374314491524), np.float64(0.6014985834525728)]}}
# ITERATION
# 3
# Unique values in column 'piv1': 13
# Unique values in column 'piv2': 8
# Unique values in column 'piv3': 7
# Unique values in column 'piv4': 8
# Unique values in column 'piv5': 9
# Unique values in column 'link': 2
# Unique values in column 'unique_id': 5000
# Unique values in column 'synthetic': 1
# Unique values in column 'duplication': 1
# 0.789
# Initial accuracy is 0.5008
# Iteration number 1 reached accuracy of 0.3859.
# /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/arfpy/arf.py:329: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.factor_cols[j]:
# 2500.0
# RangeIndex(start=0, stop=5000, step=1)
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - piv1 (no m values are trained).
#     - piv2 (no m values are trained).
#     - piv3 (no m values are trained).
#     - piv4 (no m values are trained).
#     - piv5 (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."piv1" = r."piv1") AND (l."piv2" = r."piv2") AND (l."piv3" = r."piv3")
#
# Parameter estimates will be made for the following comparison(s):
#     - piv4
#     - piv5
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - piv1
#     - piv2
#     - piv3
#
# Iteration 1: Largest change in params was 0.00327 in the m_probability of piv5, level `All other comparisons`
# Iteration 2: Largest change in params was 0.00232 in the m_probability of piv5, level `All other comparisons`
# Iteration 3: Largest change in params was -0.00173 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 4: Largest change in params was 0.00135 in the m_probability of piv5, level `All other comparisons`
# Iteration 5: Largest change in params was -0.00111 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 6: Largest change in params was -0.00096 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 7: Largest change in params was -0.000864 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 8: Largest change in params was 0.000803 in the m_probability of piv5, level `All other comparisons`
# Iteration 9: Largest change in params was 0.000766 in the m_probability of piv5, level `All other comparisons`
# Iteration 10: Largest change in params was -0.000743 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 11: Largest change in params was -0.000729 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 12: Largest change in params was 0.000721 in the m_probability of piv5, level `All other comparisons`
# Iteration 13: Largest change in params was -0.000717 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 14: Largest change in params was 0.000715 in the m_probability of piv5, level `All other comparisons`
# Iteration 15: Largest change in params was -0.000715 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 16: Largest change in params was -0.000715 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 17: Largest change in params was -0.000716 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 18: Largest change in params was 0.000718 in the m_probability of piv5, level `All other comparisons`
# Iteration 19: Largest change in params was -0.000719 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 20: Largest change in params was -0.000721 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 21: Largest change in params was 0.000723 in the m_probability of piv5, level `All other comparisons`
# Iteration 22: Largest change in params was -0.000724 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 23: Largest change in params was 0.000726 in the m_probability of piv5, level `All other comparisons`
# Iteration 24: Largest change in params was 0.000727 in the m_probability of piv5, level `All other comparisons`
# Iteration 25: Largest change in params was -0.000729 in the m_probability of piv5, level `Exact match on piv5`
#
# EM converged after 25 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - piv1 (no m values are trained).
#     - piv2 (no m values are trained).
#     - piv3 (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."piv4" = r."piv4") AND (l."piv5" = r."piv5")
#
# Parameter estimates will be made for the following comparison(s):
#     - piv1
#     - piv2
#     - piv3
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - piv4
#     - piv5
#
# Iteration 1: Largest change in params was 0.00206 in the m_probability of piv2, level `All other comparisons`
# Iteration 2: Largest change in params was -0.00118 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 3: Largest change in params was -0.000627 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 4: Largest change in params was 0.000284 in the m_probability of piv2, level `All other comparisons`
# Iteration 5: Largest change in params was 0.000379 in the m_probability of piv1, level `Exact match on piv1`
# Iteration 6: Largest change in params was 0.000503 in the m_probability of piv1, level `Exact match on piv1`
# Iteration 7: Largest change in params was -0.000577 in the m_probability of piv1, level `All other comparisons`
# Iteration 8: Largest change in params was 0.000619 in the m_probability of piv1, level `Exact match on piv1`
# Iteration 9: Largest change in params was -0.000642 in the m_probability of piv1, level `All other comparisons`
# Iteration 10: Largest change in params was 0.000652 in the m_probability of piv1, level `Exact match on piv1`
# Iteration 11: Largest change in params was -0.000654 in the m_probability of piv1, level `All other comparisons`
# Iteration 12: Largest change in params was 0.000652 in the m_probability of piv1, level `Exact match on piv1`
# Iteration 13: Largest change in params was -0.000646 in the m_probability of piv1, level `All other comparisons`
# Iteration 14: Largest change in params was 0.000639 in the m_probability of piv1, level `Exact match on piv1`
# Iteration 15: Largest change in params was -0.000631 in the m_probability of piv1, level `All other comparisons`
# Iteration 16: Largest change in params was 0.000622 in the m_probability of piv1, level `Exact match on piv1`
# Iteration 17: Largest change in params was -0.000613 in the m_probability of piv1, level `All other comparisons`
# Iteration 18: Largest change in params was 0.000604 in the m_probability of piv1, level `Exact match on piv1`
# Iteration 19: Largest change in params was 0.000595 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 20: Largest change in params was 0.000587 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 21: Largest change in params was -0.000579 in the m_probability of piv3, level `All other comparisons`
# Iteration 22: Largest change in params was -0.000571 in the m_probability of piv3, level `All other comparisons`
# Iteration 23: Largest change in params was 0.000562 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 24: Largest change in params was 0.000555 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 25: Largest change in params was -0.000547 in the m_probability of piv3, level `All other comparisons`
#
# EM converged after 25 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values
# Blocking time: 0.01 seconds
# Predict time: 0.05 seconds
# 2002
# 85
# 0.35
# {0.35: {'overlapInA': [0.34965034965034963, 0.34965034965034963, 0.34965034965034963], 'overlapInB': [0.14, 0.14, 0.14], 'difficultyInA': [0.8921078921078921, 0.9000999000999002, 0.9075924075924076], 'difficultyInB': [0.7932, 0.7902, 0.789], 'difficultyInL': [np.float64(0.9542857142857143), np.float64(0.9585714285714285), np.float64(0.9728571428571429)], 'difficultyInNL': [np.float64(0.8181395348837209), np.float64(0.8137209302325581), np.float64(0.8118604651162791)], 'ytrain_synth_prop': [synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64], 'ytest_synth_prop': [synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64], 'auc_synth': [np.float64(0.4827088), np.float64(0.5224783999999999), np.float64(0.537624)], 'ytrain_link_prop': [link    0.14
# dtype: float64, link    0.14
# dtype: float64, link    0.14
# dtype: float64], 'ytest_link_prop': [link    0.14
# dtype: float64, link    0.14
# dtype: float64, link    0.14
# dtype: float64], 'auc_link': [np.float64(0.49102591362126247), np.float64(0.5131189368770764), np.float64(0.4993076411960133)], 'max_proba_linked': [0.41406256855084755, 0.39850141654742727, 0.4058086420521753], 'median_proba_linked': [0.41, 0.39, 0.4], 'threshold_for_links': [0.41, 0.39, 0.4], 'synth_pairs_prop': [0.212, 0.214, 0.228], 'real_pairs_prop': [np.float64(0.2148), np.float64(0.2348), np.float64(0.2256)], 'true_fdr': [np.float64(0.6054114994363021), np.float64(0.6264674493062967), np.float64(0.6170678336980306)], 'hat_fdr_us': [0.5975197294250282, 0.5709711846318036, 0.6236323851203501], 'hat_fdr_prob': [np.float64(0.5859374314491524), np.float64(0.6014985834525728), np.float64(0.5941913579478247)]}}
# ITERATION
# 4
# Unique values in column 'piv1': 12
# Unique values in column 'piv2': 8
# Unique values in column 'piv3': 7
# Unique values in column 'piv4': 8
# Unique values in column 'piv5': 9
# Unique values in column 'link': 2
# Unique values in column 'unique_id': 5000
# Unique values in column 'synthetic': 1
# Unique values in column 'duplication': 1
# 0.7882
# Initial accuracy is 0.4973
# /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/arfpy/arf.py:329: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.factor_cols[j]:
# 2500.0
# RangeIndex(start=0, stop=5000, step=1)
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - piv1 (no m values are trained).
#     - piv2 (no m values are trained).
#     - piv3 (no m values are trained).
#     - piv4 (no m values are trained).
#     - piv5 (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."piv1" = r."piv1") AND (l."piv2" = r."piv2") AND (l."piv3" = r."piv3")
#
# Parameter estimates will be made for the following comparison(s):
#     - piv4
#     - piv5
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - piv1
#     - piv2
#     - piv3
#
# Iteration 1: Largest change in params was 0.00243 in the m_probability of piv5, level `All other comparisons`
# Iteration 2: Largest change in params was -0.00158 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 3: Largest change in params was -0.00106 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 4: Largest change in params was 0.000731 in the m_probability of piv5, level `All other comparisons`
# Iteration 5: Largest change in params was -0.000527 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 6: Largest change in params was 0.000398 in the m_probability of piv5, level `All other comparisons`
# Iteration 7: Largest change in params was 0.000318 in the m_probability of piv5, level `All other comparisons`
# Iteration 8: Largest change in params was -0.000267 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 9: Largest change in params was 0.000235 in the m_probability of piv5, level `All other comparisons`
# Iteration 10: Largest change in params was 0.000223 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 11: Largest change in params was -0.000233 in the m_probability of piv4, level `All other comparisons`
# Iteration 12: Largest change in params was -0.000237 in the m_probability of piv4, level `All other comparisons`
# Iteration 13: Largest change in params was -0.00024 in the m_probability of piv4, level `All other comparisons`
# Iteration 14: Largest change in params was 0.00024 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 15: Largest change in params was -0.00024 in the m_probability of piv4, level `All other comparisons`
# Iteration 16: Largest change in params was -0.000239 in the m_probability of piv4, level `All other comparisons`
# Iteration 17: Largest change in params was -0.000237 in the m_probability of piv4, level `All other comparisons`
# Iteration 18: Largest change in params was 0.000235 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 19: Largest change in params was 0.000234 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 20: Largest change in params was 0.000232 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 21: Largest change in params was -0.00023 in the m_probability of piv4, level `All other comparisons`
# Iteration 22: Largest change in params was 0.000228 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 23: Largest change in params was -0.000226 in the m_probability of piv4, level `All other comparisons`
# Iteration 24: Largest change in params was 0.000224 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 25: Largest change in params was 0.000222 in the m_probability of piv4, level `Exact match on piv4`
#
# EM converged after 25 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - piv1 (no m values are trained).
#     - piv2 (no m values are trained).
#     - piv3 (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."piv4" = r."piv4") AND (l."piv5" = r."piv5")
#
# Parameter estimates will be made for the following comparison(s):
#     - piv1
#     - piv2
#     - piv3
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - piv4
#     - piv5
#
# Iteration 1: Largest change in params was -0.00236 in the m_probability of piv1, level `Exact match on piv1`
# Iteration 2: Largest change in params was 0.0013 in the m_probability of piv1, level `All other comparisons`
# Iteration 3: Largest change in params was 0.000818 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 4: Largest change in params was -0.00116 in the m_probability of piv2, level `All other comparisons`
# Iteration 5: Largest change in params was 0.00135 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 6: Largest change in params was 0.00144 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 7: Largest change in params was 0.00147 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 8: Largest change in params was 0.00146 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 9: Largest change in params was -0.00144 in the m_probability of piv2, level `All other comparisons`
# Iteration 10: Largest change in params was -0.00141 in the m_probability of piv2, level `All other comparisons`
# Iteration 11: Largest change in params was 0.00137 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 12: Largest change in params was 0.00132 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 13: Largest change in params was 0.00128 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 14: Largest change in params was -0.00124 in the m_probability of piv2, level `All other comparisons`
# Iteration 15: Largest change in params was 0.00119 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 16: Largest change in params was -0.00115 in the m_probability of piv2, level `All other comparisons`
# Iteration 17: Largest change in params was 0.00111 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 18: Largest change in params was -0.00107 in the m_probability of piv2, level `All other comparisons`
# Iteration 19: Largest change in params was 0.00103 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 20: Largest change in params was -0.000998 in the m_probability of piv2, level `All other comparisons`
# Iteration 21: Largest change in params was 0.000962 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 22: Largest change in params was -0.000929 in the m_probability of piv2, level `All other comparisons`
# Iteration 23: Largest change in params was 0.000896 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 24: Largest change in params was -0.000865 in the m_probability of piv2, level `All other comparisons`
# Iteration 25: Largest change in params was 0.000835 in the m_probability of piv2, level `Exact match on piv2`
#
# EM converged after 25 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values
# Blocking time: 0.01 seconds
# Predict time: 0.05 seconds
# 2002
# 85
# 0.35
# {0.35: {'overlapInA': [0.34965034965034963, 0.34965034965034963, 0.34965034965034963, 0.34965034965034963], 'overlapInB': [0.14, 0.14, 0.14, 0.14], 'difficultyInA': [0.8921078921078921, 0.9000999000999002, 0.9075924075924076, 0.8981018981018981], 'difficultyInB': [0.7932, 0.7902, 0.789, 0.7882], 'difficultyInL': [np.float64(0.9542857142857143), np.float64(0.9585714285714285), np.float64(0.9728571428571429), np.float64(0.9671428571428572)], 'difficultyInNL': [np.float64(0.8181395348837209), np.float64(0.8137209302325581), np.float64(0.8118604651162791), np.float64(0.8102325581395349)], 'ytrain_synth_prop': [synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64], 'ytest_synth_prop': [synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64], 'auc_synth': [np.float64(0.4827088), np.float64(0.5224783999999999), np.float64(0.537624), np.float64(0.4746376)], 'ytrain_link_prop': [link    0.14
# dtype: float64, link    0.14
# dtype: float64, link    0.14
# dtype: float64, link    0.14
# dtype: float64], 'ytest_link_prop': [link    0.14
# dtype: float64, link    0.14
# dtype: float64, link    0.14
# dtype: float64, link    0.14
# dtype: float64], 'auc_link': [np.float64(0.49102591362126247), np.float64(0.5131189368770764), np.float64(0.4993076411960133), np.float64(0.49876279069767443)], 'max_proba_linked': [0.41406256855084755, 0.39850141654742727, 0.4058086420521753, 0.42097326473464264], 'median_proba_linked': [0.41, 0.39, 0.4, 0.42], 'threshold_for_links': [0.41, 0.39, 0.4, 0.42], 'synth_pairs_prop': [0.212, 0.214, 0.228, 0.284], 'real_pairs_prop': [np.float64(0.2148), np.float64(0.2348), np.float64(0.2256), np.float64(0.2178)], 'true_fdr': [np.float64(0.6054114994363021), np.float64(0.6264674493062967), np.float64(0.6170678336980306), np.float64(0.6087199552822806)], 'hat_fdr_us': [0.5975197294250282, 0.5709711846318036, 0.6236323851203501, 0.7937395192845165], 'hat_fdr_prob': [np.float64(0.5859374314491524), np.float64(0.6014985834525728), np.float64(0.5941913579478247), np.float64(0.5790267352653575)]}}
# ITERATION
# 5
# Unique values in column 'piv1': 11
# Unique values in column 'piv2': 8
# Unique values in column 'piv3': 7
# Unique values in column 'piv4': 8
# Unique values in column 'piv5': 9
# Unique values in column 'link': 2
# Unique values in column 'unique_id': 5000
# Unique values in column 'synthetic': 1
# Unique values in column 'duplication': 1
# 0.7862
# Initial accuracy is 0.4973
# /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/arfpy/arf.py:329: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.factor_cols[j]:
# 2500.0
# RangeIndex(start=0, stop=5000, step=1)
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - piv1 (no m values are trained).
#     - piv2 (no m values are trained).
#     - piv3 (no m values are trained).
#     - piv4 (no m values are trained).
#     - piv5 (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."piv1" = r."piv1") AND (l."piv2" = r."piv2") AND (l."piv3" = r."piv3")
#
# Parameter estimates will be made for the following comparison(s):
#     - piv4
#     - piv5
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - piv1
#     - piv2
#     - piv3
#
# Iteration 1: Largest change in params was -0.00329 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 2: Largest change in params was 0.00193 in the m_probability of piv4, level `All other comparisons`
# Iteration 3: Largest change in params was -0.00106 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 4: Largest change in params was -0.0005 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 5: Largest change in params was -0.000707 in the m_probability of piv5, level `All other comparisons`
# Iteration 6: Largest change in params was -0.000905 in the m_probability of piv5, level `All other comparisons`
# Iteration 7: Largest change in params was 0.00102 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 8: Largest change in params was 0.00108 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 9: Largest change in params was 0.00111 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 10: Largest change in params was -0.00112 in the m_probability of piv5, level `All other comparisons`
# Iteration 11: Largest change in params was 0.00111 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 12: Largest change in params was -0.0011 in the m_probability of piv5, level `All other comparisons`
# Iteration 13: Largest change in params was 0.00108 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 14: Largest change in params was -0.00106 in the m_probability of piv5, level `All other comparisons`
# Iteration 15: Largest change in params was -0.00103 in the m_probability of piv5, level `All other comparisons`
# Iteration 16: Largest change in params was 0.00101 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 17: Largest change in params was 0.000986 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 18: Largest change in params was -0.000962 in the m_probability of piv5, level `All other comparisons`
# Iteration 19: Largest change in params was -0.000938 in the m_probability of piv5, level `All other comparisons`
# Iteration 20: Largest change in params was -0.000915 in the m_probability of piv5, level `All other comparisons`
# Iteration 21: Largest change in params was 0.000892 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 22: Largest change in params was -0.00087 in the m_probability of piv5, level `All other comparisons`
# Iteration 23: Largest change in params was 0.000848 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 24: Largest change in params was 0.000827 in the m_probability of piv5, level `Exact match on piv5`
# Iteration 25: Largest change in params was -0.000806 in the m_probability of piv5, level `All other comparisons`
#
# EM converged after 25 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - piv1 (no m values are trained).
#     - piv2 (no m values are trained).
#     - piv3 (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."piv4" = r."piv4") AND (l."piv5" = r."piv5")
#
# Parameter estimates will be made for the following comparison(s):
#     - piv1
#     - piv2
#     - piv3
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - piv4
#     - piv5
#
# Iteration 1: Largest change in params was -0.00367 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 2: Largest change in params was -0.00226 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 3: Largest change in params was -0.00137 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 4: Largest change in params was 0.0008 in the m_probability of piv3, level `All other comparisons`
# Iteration 5: Largest change in params was 0.000435 in the m_probability of piv3, level `All other comparisons`
# Iteration 6: Largest change in params was 0.000199 in the m_probability of piv3, level `All other comparisons`
# Iteration 7: Largest change in params was 7.91e-05 in the m_probability of piv1, level `Exact match on piv1`
#
# EM converged after 7 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values
# Blocking time: 0.01 seconds
# Predict time: 0.05 seconds
# 2002
# 85
# 0.35
# {0.35: {'overlapInA': [0.34965034965034963, 0.34965034965034963, 0.34965034965034963, 0.34965034965034963, 0.34965034965034963], 'overlapInB': [0.14, 0.14, 0.14, 0.14, 0.14], 'difficultyInA': [0.8921078921078921, 0.9000999000999002, 0.9075924075924076, 0.8981018981018981, 0.8956043956043956], 'difficultyInB': [0.7932, 0.7902, 0.789, 0.7882, 0.7862], 'difficultyInL': [np.float64(0.9542857142857143), np.float64(0.9585714285714285), np.float64(0.9728571428571429), np.float64(0.9671428571428572), np.float64(0.9642857142857143)], 'difficultyInNL': [np.float64(0.8181395348837209), np.float64(0.8137209302325581), np.float64(0.8118604651162791), np.float64(0.8102325581395349), np.float64(0.8102325581395349)], 'ytrain_synth_prop': [synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64], 'ytest_synth_prop': [synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64], 'auc_synth': [np.float64(0.4827088), np.float64(0.5224783999999999), np.float64(0.537624), np.float64(0.4746376), np.float64(0.4787968)], 'ytrain_link_prop': [link    0.14
# dtype: float64, link    0.14
# dtype: float64, link    0.14
# dtype: float64, link    0.14
# dtype: float64, link    0.14
# dtype: float64], 'ytest_link_prop': [link    0.14
# dtype: float64, link    0.14
# dtype: float64, link    0.14
# dtype: float64, link    0.14
# dtype: float64, link    0.14
# dtype: float64], 'auc_link': [np.float64(0.49102591362126247), np.float64(0.5131189368770764), np.float64(0.4993076411960133), np.float64(0.49876279069767443), np.float64(0.49270431893687705)], 'max_proba_linked': [0.41406256855084755, 0.39850141654742727, 0.4058086420521753, 0.42097326473464264, 0.39949715918294654], 'median_proba_linked': [0.41, 0.39, 0.4, 0.42, 0.39], 'threshold_for_links': [0.41, 0.39, 0.4, 0.42, 0.39], 'synth_pairs_prop': [0.212, 0.214, 0.228, 0.284, 0.254], 'real_pairs_prop': [np.float64(0.2148), np.float64(0.2348), np.float64(0.2256), np.float64(0.2178), np.float64(0.2264)], 'true_fdr': [np.float64(0.6054114994363021), np.float64(0.6264674493062967), np.float64(0.6170678336980306), np.float64(0.6087199552822806), np.float64(0.6179039301310044)], 'hat_fdr_us': [0.5975197294250282, 0.5709711846318036, 0.6236323851203501, 0.7937395192845165, 0.6932314410480349], 'hat_fdr_prob': [np.float64(0.5859374314491524), np.float64(0.6014985834525728), np.float64(0.5941913579478247), np.float64(0.5790267352653575), np.float64(0.6005028408170536)]}}
# ITERATION
# 6
# Unique values in column 'piv1': 12
# Unique values in column 'piv2': 8
# Unique values in column 'piv3': 7
# Unique values in column 'piv4': 8
# Unique values in column 'piv5': 9
# Unique values in column 'link': 2
# Unique values in column 'unique_id': 5000
# Unique values in column 'synthetic': 1
# Unique values in column 'duplication': 1
# 0.7836
# Initial accuracy is 0.5017
# Iteration number 1 reached accuracy of 0.3873.
# /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages/arfpy/arf.py:329: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if self.factor_cols[j]:
# 2500.0
# RangeIndex(start=0, stop=5000, step=1)
# ----- Estimating u probabilities using random sampling -----
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - piv1 (no m values are trained).
#     - piv2 (no m values are trained).
#     - piv3 (no m values are trained).
#     - piv4 (no m values are trained).
#     - piv5 (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."piv1" = r."piv1") AND (l."piv2" = r."piv2") AND (l."piv3" = r."piv3")
#
# Parameter estimates will be made for the following comparison(s):
#     - piv4
#     - piv5
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - piv1
#     - piv2
#     - piv3
#
# Iteration 1: Largest change in params was -0.00255 in the m_probability of piv4, level `Exact match on piv4`
# ...
# Iteration 1: Largest change in params was 0.0129 in the m_probability of piv4, level `All other comparisons`
# Iteration 2: Largest change in params was -0.00921 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 3: Largest change in params was -0.00911 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 4: Largest change in params was 0.00943 in the m_probability of piv4, level `All other comparisons`
# Iteration 5: Largest change in params was -0.00969 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 6: Largest change in params was 0.00981 in the m_probability of piv4, level `All other comparisons`
# Iteration 7: Largest change in params was 0.00976 in the m_probability of piv4, level `All other comparisons`
# Iteration 8: Largest change in params was -0.00955 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 9: Largest change in params was -0.0092 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 10: Largest change in params was 0.00872 in the m_probability of piv4, level `All other comparisons`
# Iteration 11: Largest change in params was -0.00814 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 12: Largest change in params was 0.00749 in the m_probability of piv4, level `All other comparisons`
# Iteration 13: Largest change in params was 0.00681 in the m_probability of piv4, level `All other comparisons`
# Iteration 14: Largest change in params was 0.00611 in the m_probability of piv4, level `All other comparisons`
# Iteration 15: Largest change in params was -0.00543 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 16: Largest change in params was -0.00478 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 17: Largest change in params was -0.00417 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 18: Largest change in params was 0.00361 in the m_probability of piv4, level `All other comparisons`
# Iteration 19: Largest change in params was -0.0031 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 20: Largest change in params was 0.00265 in the m_probability of piv4, level `All other comparisons`
# Iteration 21: Largest change in params was -0.00226 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 22: Largest change in params was -0.00191 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 23: Largest change in params was 0.00161 in the m_probability of piv4, level `All other comparisons`
# Iteration 24: Largest change in params was -0.00136 in the m_probability of piv4, level `Exact match on piv4`
# Iteration 25: Largest change in params was 0.00114 in the m_probability of piv4, level `All other comparisons`
#
# EM converged after 25 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - piv1 (no m values are trained).
#     - piv2 (no m values are trained).
#     - piv3 (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# (l."piv4" = r."piv4") AND (l."piv5" = r."piv5")
#
# Parameter estimates will be made for the following comparison(s):
#     - piv1
#     - piv2
#     - piv3
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - piv4
#     - piv5
#
# Iteration 1: Largest change in params was 0.0216 in the m_probability of piv1, level `Exact match on piv1`
# Iteration 2: Largest change in params was 0.0239 in the m_probability of piv2, level `All other comparisons`
# Iteration 3: Largest change in params was -0.0324 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 4: Largest change in params was 0.0335 in the m_probability of piv2, level `All other comparisons`
# Iteration 5: Largest change in params was -0.0285 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 6: Largest change in params was -0.0207 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 7: Largest change in params was -0.0134 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 8: Largest change in params was -0.00806 in the m_probability of piv2, level `Exact match on piv2`
# Iteration 9: Largest change in params was 0.00465 in the m_probability of piv2, level `All other comparisons`
# Iteration 10: Largest change in params was -0.00444 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 11: Largest change in params was -0.00465 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 12: Largest change in params was 0.00481 in the m_probability of piv3, level `All other comparisons`
# Iteration 13: Largest change in params was -0.00493 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 14: Largest change in params was 0.005 in the m_probability of piv3, level `All other comparisons`
# Iteration 15: Largest change in params was -0.00502 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 16: Largest change in params was 0.005 in the m_probability of piv3, level `All other comparisons`
# Iteration 17: Largest change in params was -0.00494 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 18: Largest change in params was -0.00484 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 19: Largest change in params was -0.00471 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 20: Largest change in params was -0.00455 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 21: Largest change in params was 0.00437 in the m_probability of piv3, level `All other comparisons`
# Iteration 22: Largest change in params was -0.00417 in the m_probability of piv3, level `Exact match on piv3`
# Iteration 23: Largest change in params was 0.00395 in the m_probability of piv3, level `All other comparisons`
# Iteration 24: Largest change in params was 0.00372 in the m_probability of piv3, level `All other comparisons`
# Iteration 25: Largest change in params was -0.00349 in the m_probability of piv3, level `Exact match on piv3`
#
# EM converged after 25 iterations
#
# Your model is fully trained. All comparisons have at least one estimate for their m and u values
# Blocking time: 0.01 seconds
# Predict time: 0.05 seconds
# 4502
# 95
# 0.75
# {0.35: {'overlapInA': [0.33607285650821855, 0.3385162150155486, 0.3349622390048867, 0.3125277654375833, 0.23367392270102177, 0.3276321634828965, 0.33229675699689026, 0.32207907596623725, 0.33318525099955576, 0.3302976454908929], 'overlapInB': [0.3026, 0.3048, 0.3016, 0.2814, 0.2104, 0.295, 0.2992, 0.29, 0.3, 0.2974], 'difficultyInA': [0.9435806308307418, 0.9404709018214127, 0.9375832963127498, 0.938249666814749, 0.9369169258107508, 0.9386939138160817, 0.9433585073300755, 0.9369169258107508, 0.9420257663260773, 0.9415815193247445], 'difficultyInB': [0.9468, 0.953, 0.9536, 0.9482, 0.9444, 0.9492, 0.9528, 0.9458, 0.9524, 0.946], 'difficultyInL': [np.float64(0.9781890284203569), np.float64(0.9776902887139107), np.float64(0.976790450928382), np.float64(0.9786780383795309), np.float64(0.9838403041825095), np.float64(0.9749152542372881), np.float64(0.9792780748663101), np.float64(0.9751724137931035), np.float64(0.9766666666666667), np.float64(0.9737726967047747)], 'difficultyInNL': [np.float64(0.9331803842844852), np.float64(0.942174913693901), np.float64(0.9435853379152348), np.float64(0.9362649596437518), np.float64(0.9338905775075987), np.float64(0.9384397163120567), np.float64(0.9414954337899544), np.float64(0.9338028169014084), np.float64(0.942), np.float64(0.9342442356959864)], 'ytrain_synth_prop': [synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64], 'ytest_synth_prop': [synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64], 'auc_synth': [np.float64(0.5457832), np.float64(0.49154319999999996), np.float64(0.5067072), np.float64(0.515252), np.float64(0.5045240000000001), np.float64(0.5125856), np.float64(0.5498624), np.float64(0.5460192), np.float64(0.5209656), np.float64(0.5399776)], 'ytrain_link_prop': [link    0.302521
# dtype: float64, link    0.3048
# dtype: float64, link    0.3016
# dtype: float64, link    0.281313
# dtype: float64, link    0.2104
# dtype: float64, link    0.294918
# dtype: float64, link    0.2992
# dtype: float64, link    0.29
# dtype: float64, link    0.3
# dtype: float64, link    0.297319
# dtype: float64], 'ytest_link_prop': [link    0.302679
# dtype: float64, link    0.3048
# dtype: float64, link    0.3016
# dtype: float64, link    0.281487
# dtype: float64, link    0.2104
# dtype: float64, link    0.295082
# dtype: float64, link    0.2992
# dtype: float64, link    0.29
# dtype: float64, link    0.3
# dtype: float64, link    0.297481
# dtype: float64], 'auc_link': [np.float64(0.9994266055045872), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(0.9997163925127623), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(1.0)], 'max_proba_linked': [0.7326976577658454, 0.7453075704356866, 0.7527938309533302, 0.7322238131669173, 0.681354267559045, 0.7447931846221559, 0.7468090544153095, 0.7478974568967074, 0.7563796101704434, 0.7375814625319909], 'median_proba_linked': [0.73, 0.74, 0.75, 0.73, 0.68, 0.74, 0.74, 0.74, 0.75, 0.73], 'threshold_for_links': [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5], 'synth_pairs_prop': [0.07, 0.064, 0.074, 0.072, 0.104, 0.098, 0.094, 0.08, 0.078, 0.074], 'real_pairs_prop': [np.float64(0.094), np.float64(0.0924), np.float64(0.1036), np.float64(0.1084), np.float64(0.1048), np.float64(0.0898), np.float64(0.1016), np.float64(0.1104), np.float64(0.0984), np.float64(0.0936)], 'true_fdr': [np.float64(0.23701462430660616), np.float64(0.2326283987915408), np.float64(0.25567620927936824), np.float64(0.27809132888660854), np.float64(0.33248730964467005), np.float64(0.23336798336798337), np.float64(0.25349301397205587), np.float64(0.2757242757242757), np.float64(0.2469879518072289), np.float64(0.239386189258312)], 'hat_fdr_us': [0.17650025214321735, 0.16112789526686808, 0.18262586377097728, 0.18471010774756286, 0.3299492385786802, 0.25467775467775466, 0.2345309381237525, 0.1998001998001998, 0.19578313253012047, 0.18925831202046037], 'hat_fdr_prob': [np.float64(0.2673023422341545), np.float64(0.25469242956431337), np.float64(0.24720616904667003), np.float64(0.26777618683308246), np.float64(0.31864573244095484), np.float64(0.2552068153778442), np.float64(0.25319094558469035), np.float64(0.2521025431032927), np.float64(0.2436203898295568), np.float64(0.26241853746800925)]}, 0.75: {'overlapInA': [0.6717014660151044, 0.6539315859617948, 0.6694802310084407, 0.6523767214571302, 0.6719235895157708, 0.667258996001777, 0.6663705019991115, 0.6737005775211017, 0.673256330519769, 0.6770324300310973], 'overlapInB': [0.6048, 0.5888, 0.6028, 0.5874, 0.605, 0.6008, 0.6, 0.6066, 0.6062, 0.6096], 'difficultyInA': [0.9362505553087517, 0.9422478898267437, 0.9464682363394047, 0.9429142603287428, 0.9409151488227454, 0.9424700133274101, 0.9438027543314083, 0.9366948023100844, 0.9433585073300755, 0.9424700133274101], 'difficultyInB': [0.953, 0.9578, 0.956, 0.9534, 0.9508, 0.9554, 0.957, 0.9554, 0.9566, 0.9576], 'difficultyInL': [np.float64(0.9447751322751323), np.float64(0.9551630434782609), np.float64(0.9528865295288653), np.float64(0.9499489274770173), np.float64(0.943801652892562), np.float64(0.9513981358189081), np.float64(0.955), np.float64(0.948236069897791), np.float64(0.954140547674035), np.float64(0.9520997375328084)], 'difficultyInNL': [np.float64(0.9655870445344129), np.float64(0.9615758754863813), np.float64(0.9607250755287009), np.float64(0.9583131362094037), np.float64(0.9615189873417721), np.float64(0.9614228456913828), np.float64(0.96), np.float64(0.9664463650228775), np.float64(0.9603859827323514), np.float64(0.9661885245901639)], 'ytrain_synth_prop': [synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64, synthetic    0.091206
# dtype: float64], 'ytest_synth_prop': [synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64, synthetic    0.090909
# dtype: float64], 'auc_synth': [np.float64(0.5708336), np.float64(0.5564512), np.float64(0.5207936), np.float64(0.5453184), np.float64(0.5154648), np.float64(0.5043176), np.float64(0.532456), np.float64(0.5325479999999999), np.float64(0.5490152), np.float64(0.545512)], 'ytrain_link_prop': [link    0.6048
# dtype: float64, link    0.5888
# dtype: float64, link    0.6028
# dtype: float64, link    0.587435
# dtype: float64, link    0.605042
# dtype: float64, link    0.6008
# dtype: float64, link    0.6
# dtype: float64, link    0.606643
# dtype: float64, link    0.606242
# dtype: float64, link    0.6096
# dtype: float64], 'ytest_link_prop': [link    0.6048
# dtype: float64, link    0.5888
# dtype: float64, link    0.6028
# dtype: float64, link    0.587365
# dtype: float64, link    0.604958
# dtype: float64, link    0.6008
# dtype: float64, link    0.6
# dtype: float64, link    0.606557
# dtype: float64, link    0.606158
# dtype: float64, link    0.6096
# dtype: float64], 'auc_link': [np.float64(1.0), np.float64(1.0), np.float64(0.999496475327291), np.float64(1.0), np.float64(0.999493927125506), np.float64(0.9994989979959921), np.float64(1.0), np.float64(1.0), np.float64(0.998984771573604), np.float64(0.9994877049180328)], 'max_proba_linked': [0.8420870800556624, 0.8417112264950876, 0.848612597564193, 0.8493101479206876, 0.8541826682393511, 0.8440893234525203, 0.8284881404695498, 0.8456540718480684, 0.8552275927909658, 0.8464761802822699], 'median_proba_linked': [0.84, 0.84, 0.84, 0.84, 0.85, 0.84, 0.82, 0.84, 0.85, 0.84], 'threshold_for_links': [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5], 'synth_pairs_prop': [0.088, 0.096, 0.092, 0.068, 0.096, 0.118, 0.096, 0.106, 0.104, 0.074], 'real_pairs_prop': [np.float64(0.0972), np.float64(0.0906), np.float64(0.0884), np.float64(0.0974), np.float64(0.1046), np.float64(0.094), np.float64(0.0874), np.float64(0.0978), np.float64(0.0908), np.float64(0.0988)], 'true_fdr': [np.float64(0.13846153846153847), np.float64(0.13335295849278775), np.float64(0.12789351851851852), np.float64(0.14223130841121495), np.float64(0.14740698985343856), np.float64(0.13529073114565343), np.float64(0.12714576665696828), np.float64(0.13884156729131175), np.float64(0.1302725968436155), np.float64(0.13946922642574816)], 'hat_fdr_us': [0.12535612535612536, 0.1413011480718281, 0.13310185185185186, 0.09929906542056074, 0.13528748590755355, 0.16983304548071387, 0.13965667733488507, 0.15048268029528677, 0.1492109038737446, 0.10446075663466968], 'hat_fdr_prob': [np.float64(0.15791291994433732), np.float64(0.15828877350491255), np.float64(0.15138740243580695), np.float64(0.15068985207931251), np.float64(0.14581733176064893), np.float64(0.1559106765474797), np.float64(0.17151185953045067), np.float64(0.1543459281519316), np.float64(0.14477240720903417), np.float64(0.15352381971773021)]}}

# %%
print("done")
# Out:
# done

# %%
for linkage in dico_results_final.keys():

    first_dico = dico_results_final[linkage]
    
    for nA in first_dico.keys():

        second_dico = first_dico[nA]
    
        for list_params_key in second_dico.keys():
        
            third_dico = second_dico[list_params_key]
    
            for overlap in third_dico.keys():

                fourth_dico = third_dico[overlap]

                print(len(np.nonzero(fourth_dico["true_fdr"])[0]))

                print(linkage)
                print(nA)
                print(list_params_key)
                print(overlap)
        
                print(f"overlap A: {np.mean(fourth_dico["overlapInA"])}")
                print(f"difficulty A: {np.mean(fourth_dico["difficultyInA"])}")
                print(f"overlap B: {np.mean(fourth_dico["overlapInB"])}")
                print(f"difficulty B: {np.mean(fourth_dico["difficultyInB"])}")
        
                print(f"difficulty Links: {np.mean(fourth_dico["difficultyInL"])}")
        
                print(f"difficulty Non Links: {np.mean(fourth_dico["difficultyInNL"])}")

                print(np.mean(np.array([np.mean(fourth_dico["difficultyInNL"]),np.mean(fourth_dico["difficultyInL"])])))
                print(np.mean(np.array([np.mean(fourth_dico["difficultyInA"]),np.mean(fourth_dico["difficultyInB"])])))
        
                print(f"threshold max: {np.mean(fourth_dico["max_proba_linked"])}")
                print(f"threshold median: {np.mean(fourth_dico["median_proba_linked"])}")
                print(f"threshold applied: {np.mean(fourth_dico["threshold_for_links"])}")
        
                print(f"auc synth: {np.mean(fourth_dico["auc_synth"])} and {np.std(fourth_dico["auc_synth"])}")
                print(f"auc link: {np.mean(fourth_dico["auc_link"])} and {np.std(fourth_dico["auc_link"])}")
            
                cond_synthfpprop = np.array(fourth_dico["synth_pairs_prop"]) / nA
                cond_realfpprop = np.array(fourth_dico["real_pairs_prop"]) / nA
        
                equation_check = cond_synthfpprop - cond_realfpprop
        
                print(f"condition: {np.mean(equation_check)} and {np.std(equation_check)}")
        
                FDP = np.array(fourth_dico["true_fdr"])
            
                our_estimate = np.array(fourth_dico["hat_fdr_us"])
            
                probabilistic_estimate = np.array(fourth_dico["hat_fdr_prob"])
        
                print(f"True FDP: {np.mean(FDP[np.nonzero(FDP)[0]])} and {np.std(FDP[np.nonzero(FDP)[0]])}")
                print(f"bias our FDP: {np.mean(our_estimate[np.nonzero(FDP)[0]] - FDP[np.nonzero(FDP)[0]])} and {np.std(our_estimate[np.nonzero(FDP)[0]] - FDP[np.nonzero(FDP)[0]])}")
                print(f"bias other FDP: {np.mean(probabilistic_estimate[np.nonzero(FDP)[0]] - FDP[np.nonzero(FDP)[0]])} and {np.std(probabilistic_estimate[np.nonzero(FDP)[0]] - FDP[np.nonzero(FDP)[0]])}")
        
                print("\n")
        
                # plt.show(plt.hist(our_estimate - FDP))
                # plt.show(plt.hist(probabilistic_estimate - FDP))
# Out:
# 10
# at_random
# 2002
# 85
# 0.35
# overlap A: 0.34965034965034963
# difficulty A: 0.8995504495504495
# overlap B: 0.14000000000000004
# difficulty B: 0.78682
# difficulty Links: 0.9640000000000001
# difficulty Non Links: 0.8101627906976745
# 0.8870813953488372
# 0.8431852247752247
# threshold max: 0.4084039851448347
# threshold median: 0.403
# threshold applied: 0.403
# auc synth: 0.49541752 and 0.023479207529931653
# auc link: 0.49846126245847183 and 0.008095058921653684
# condition: 2.6073926073926034e-06 and 1.4636332918295081e-05
# True FDP: 0.6160486678783491 and 0.007745753666594387
# bias our FDP: 0.015136488168373163 and 0.08082513150700617
# bias other FDP: -0.024452653023183814 and 0.010921704673069398
#
#
# 10
# at_random
# 2002
# 85
# 0.75
# overlap A: 0.7497502497502497
# difficulty A: 0.9023476523476524
# overlap B: 0.3002000000000001
# difficulty B: 0.7906
# difficulty Links: 0.9231179213857427
# difficulty Non Links: 0.8425835953129466
# 0.8828507583493446
# 0.8464738261738262
# threshold max: 0.4447883718451494
# threshold median: 0.43900000000000006
# threshold applied: 0.43900000000000006
# auc synth: 0.5044012 and 0.008637017553762422
# auc link: 0.5029445691459007 and 0.01142711291965047
# condition: 9.5004995004995e-06 and 1.277475432677407e-05
# True FDP: 0.4221152060622219 and 0.00805692052972138
# bias our FDP: 0.03678930725847591 and 0.049301500896717816
# bias other FDP: 0.1330964220926287 and 0.01078492084970277
#
#
# 10
# at_random
# 2002
# 95
# 0.35
# overlap A: 0.34965034965034963
# difficulty A: 0.9637362637362639
# overlap B: 0.14000000000000004
# difficulty B: 0.9152800000000001
# difficulty Links: 0.9872857142857143
# difficulty Non Links: 0.9257209302325581
# 0.9565033222591361
# 0.939508131868132
# threshold max: 0.6793688695195732
# threshold median: 0.675
# threshold applied: 0.5
# auc synth: 0.5208017599999999 and 0.01793021052253431
# auc link: 0.4979048504983389 and 0.01048486373014226
# condition: -3.646353646353646e-06 and 3.399320180454297e-06
# True FDP: 0.3514564281145508 and 0.00788712303650223
# bias our FDP: -0.033848843465778086 and 0.03156165051450975
# bias other FDP: -0.03082529763412405 and 0.012802303608881533
#
#
# 10
# at_random
# 2002
# 95
# 0.75
# overlap A: 0.7497502497502497
# difficulty A: 0.9635864135864136
# overlap B: 0.3002000000000001
# difficulty B: 0.91414
# difficulty Links: 0.9724850099933379
# difficulty Non Links: 0.9386110317233495
# 0.9555480208583437
# 0.9388632067932068
# threshold max: 0.7026126381979028
# threshold median: 0.6970000000000001
# threshold applied: 0.5
# auc synth: 0.50886544 and 0.01601271898780465
# auc link: 0.503181244055545 and 0.010071559435619718
# condition: 8.061938061938062e-06 and 8.438105566255964e-06
# True FDP: 0.20210020480502572 and 0.00612190999038078
# bias our FDP: 0.04306266391545376 and 0.04486255498648632
# bias other FDP: 0.09528715699707155 and 0.0067915138303501175
#
#
# 10
# at_random
# 4502
# 85
# 0.35
# overlap A: 0.34984451354953355
# difficulty A: 0.8058418480675253
# overlap B: 0.315
# difficulty B: 0.7896400000000001
# difficulty Links: 0.9226031746031745
# difficulty Non Links: 0.8435620437956205
# 0.8830826091993975
# 0.7977409240337627
# threshold max: 0.408498709703799
# threshold median: 0.40499999999999997
# threshold applied: 0.40499999999999997
# auc synth: 0.4990110399999999 and 0.021272551965159224
# auc link: 0.49715648623100145 and 0.012667077421067029
# condition: -1.4882274544646806e-06 and 7.900786479446067e-06
# True FDP: 0.6110106484154771 and 0.007634792965634493
# bias our FDP: -0.007809155666543499 and 0.044115887082816926
# bias other FDP: -0.01950935811927611 and 0.010365068779668554
#
#
# 10
# at_random
# 4502
# 85
# 0.75
# overlap A: 0.7498889382496668
# difficulty A: 0.8051310528653932
# overlap B: 0.6752
# difficulty B: 0.7875
# difficulty Links: 0.8457938388625592
# difficulty Non Links: 0.9137315270935961
# 0.8797626829780776
# 0.7963155264326967
# threshold max: 0.43874317185602435
# threshold median: 0.43499999999999994
# threshold applied: 0.43499999999999994
# auc synth: 0.49806296000000005 and 0.011994464206057697
# auc link: 0.5014894692760254 and 0.015740741849720744
# condition: 1.5593069746779215e-05 and 6.858402554921312e-06
# True FDP: 0.42457614233689717 and 0.007606882298500096
# bias our FDP: 0.05965717509211732 and 0.02597440638644041
# bias other FDP: 0.1366806858070786 and 0.005232193836244255
#
#
# 10
# at_random
# 4502
# 95
# 0.35
# overlap A: 0.34984451354953355
# difficulty A: 0.922767658818303
# overlap B: 0.315
# difficulty B: 0.9136599999999999
# difficulty Links: 0.9686349206349206
# difficulty Non Links: 0.9397080291970804
# 0.9541714749160005
# 0.9182138294091515
# threshold max: 0.6727476714653943
# threshold median: 0.6679999999999999
# threshold applied: 0.5
# auc synth: 0.50162008 and 0.01863515866896763
# auc link: 0.5063795520074912 and 0.008591708719137687
# condition: -2.047978676143938e-06 and 4.542388115314892e-06
# True FDP: 0.35544507017870874 and 0.009633704032676977
# bias our FDP: -0.018846337921872076 and 0.041462383814877525
# bias other FDP: -0.02819274164410309 and 0.01282449331165692
#
#
# 10
# at_random
# 4502
# 95
# 0.75
# overlap A: 0.7498889382496668
# difficulty A: 0.9201243891603733
# overlap B: 0.6752
# difficulty B: 0.9134
# difficulty Links: 0.9386552132701421
# difficulty Non Links: 0.9713054187192119
# 0.954980315994677
# 0.9167621945801867
# threshold max: 0.6971666597421765
# threshold median: 0.692
# threshold applied: 0.5
# auc synth: 0.50858728 and 0.011208620136734036
# auc link: 0.5049813009245208 and 0.01328675115785508
# condition: 5.970679697912039e-06 and 5.871701872039343e-06
# True FDP: 0.20589927121463267 and 0.006086492766350646
# bias our FDP: 0.03162138904033198 and 0.03124779788616101
# bias other FDP: 0.09693406904319073 and 0.006745834229707821
#
#
# 10
# strong_dep_pivs
# 2002
# 85
# 0.35
# overlap A: 0.2876123876123876
# difficulty A: 0.921828171828172
# overlap B: 0.11516
# difficulty B: 0.83004
# difficulty Links: 0.9741574522732807
# difficulty Non Links: 0.8112920049207437
# 0.8927247285970121
# 0.8759340859140861
# threshold max: 0.37307334501727496
# threshold median: 0.369
# threshold applied: 0.369
# auc synth: 0.48049008000000004 and 0.02282812321452641
# auc link: 0.9999319822776501 and 0.00014534688158754336
# condition: -1.0819180819180818e-05 and 5.786285882176502e-06
# True FDP: 0.5634635400862226 and 0.006595224085892742
# bias our FDP: -0.08209921722911154 and 0.04398670814101397
# bias other FDP: 0.06346311489650247 and 0.02595128737046012
#
#
# 10
# strong_dep_pivs
# 2002
# 85
# 0.75
# overlap A: 0.714935064935065
# difficulty A: 0.9292207792207792
# overlap B: 0.28626
# difficulty B: 0.8680200000000001
# difficulty Links: 0.9399547377487405
# difficulty Non Links: 0.8391948439217025
# 0.8895747908352215
# 0.8986203896103897
# threshold max: 0.6967890164948761
# threshold median: 0.6920000000000001
# threshold applied: 0.5
# auc synth: 0.43999176 and 0.024530953904453045
# auc link: 0.9996901085048151 and 0.0005562660578863547
# condition: -4.555444555444556e-06 and 8.820019089196783e-06
# True FDP: 0.23731516193120877 and 0.011655916640013761
# bias our FDP: -0.02388873758921344 and 0.046966730598424516
# bias other FDP: 0.06589582157391513 and 0.02283465816671794
#
#
# 10
# strong_dep_pivs
# 2002
# 95
# 0.35
# overlap A: 0.33376623376623377
# difficulty A: 0.9731768231768232
# overlap B: 0.13364000000000004
# difficulty B: 0.93218
# difficulty Links: 0.9898279778269808
# difficulty Non Links: 0.9232918165697634
# 0.9565598971983722
# 0.9526784115884116
# threshold max: 0.7220747788028234
# threshold median: 0.717
# threshold applied: 0.5
# auc synth: 0.47949216000000006 and 0.02872415042500649
# auc link: 0.9997918869416539 and 0.0003186911545441049
# condition: -2.727272727272728e-06 and 4.856634905763622e-06
# True FDP: 0.2569944488885531 and 0.014683693160538058
# bias our FDP: -0.029768581816153345 and 0.053866139475315614
# bias other FDP: 0.02093077230862337 and 0.026434877501098818
#
#
# 10
# strong_dep_pivs
# 2002
# 95
# 0.75
# overlap A: 0.6652847152847153
# difficulty A: 0.9727272727272729
# overlap B: 0.26637999999999995
# difficulty B: 0.9465600000000001
# difficulty Links: 0.9770092199797974
# difficulty Non Links: 0.9355102487653376
# 0.9562597343725675
# 0.9596436363636365
# threshold max: 0.8979721497361028
# threshold median: 0.8930000000000001
# threshold applied: 0.5
# auc synth: 0.46624304 and 0.022209825604502173
# auc link: 0.9998089626665596 and 0.0002456319472718588
# condition: -2.697302697302697e-06 and 4.466998086201051e-06
# True FDP: 0.11073566429734953 and 0.013004768032877197
# bias our FDP: -0.017917024919431913 and 0.029882424165717153
# bias other FDP: -0.00870781403345231 and 0.008013622276090274
#
#
# 10
# strong_dep_pivs
# 4502
# 85
# 0.35
# overlap A: 0.2868725011106175
# difficulty A: 0.8450688582852066
# overlap B: 0.2583
# difficulty B: 0.86494
# difficulty Links: 0.946986329256817
# difficulty Non Links: 0.836384456192037
# 0.891685392724427
# 0.8550044291426033
# threshold max: 0.39051934200635613
# threshold median: 0.386
# threshold applied: 0.386
# auc synth: 0.51318808 and 0.013359375503727702
# auc link: 0.999946003926086 and 0.00010799263978731502
# condition: -7.196801421590405e-06 and 7.361589700753596e-06
# True FDP: 0.5354969413443985 and 0.004816382204308023
# bias our FDP: -0.05822094927409296 and 0.059343183709978056
# bias other FDP: 0.07398371664924533 and 0.026105935529018708
#
#
# 10
# strong_dep_pivs
# 4502
# 85
# 0.75
# overlap A: 0.7147267880941803
# difficulty A: 0.8539315859617946
# overlap B: 0.64354
# difficulty B: 0.8864599999999999
# difficulty Links: 0.8741398613192451
# difficulty Non Links: 0.9086817519380344
# 0.8914108066286397
# 0.8701957929808972
# threshold max: 0.5604054623587958
# threshold median: 0.5549999999999999
# threshold applied: 0.5
# auc synth: 0.5184757600000001 and 0.024814712794598293
# auc link: 0.9995471028256653 and 0.0006670818905661356
# condition: 8.014215904042648e-06 and 7.0223971484294475e-06
# True FDP: 0.3017310533649093 and 0.005641787140049739
# bias our FDP: 0.03910183407565736 and 0.03438216296149892
# bias other FDP: 0.13786348427629475 and 0.019949681189138656
#
#
# 10
# strong_dep_pivs
# 4502
# 95
# 0.35
# overlap A: 0.32012438916037317
# difficulty A: 0.9399378054198134
# overlap B: 0.28823999999999994
# difficulty B: 0.9492200000000001
# difficulty Links: 0.9774993216892833
# difficulty Non Links: 0.9379078375744377
# 0.9577035796318605
# 0.9445789027099067
# threshold max: 0.7377837908517431
# threshold median: 0.733
# threshold applied: 0.5
# auc synth: 0.5233220000000001 and 0.019562020742244394
# auc link: 0.999914299801735 and 0.00018324006504045516
# condition: -4.198134162594401e-06 and 3.0307447303268314e-06
# True FDP: 0.258485728503865 and 0.029065622114478978
# bias our FDP: -0.0475893590379056 and 0.03450008278761879
# bias other FDP: 0.003730480644391887 and 0.017920873494453624
#
#
# 10
# strong_dep_pivs
# 4502
# 95
# 0.75
# overlap A: 0.6677032430031098
# difficulty A: 0.9417592181252777
# overlap B: 0.6012000000000001
# difficulty B: 0.9552999999999999
# difficulty Links: 0.9507449776575381
# difficulty Non Links: 0.9622163837137446
# 0.9564806806856414
# 0.9485296090626388
# threshold max: 0.8455839029118355
# threshold median: 0.8399999999999999
# threshold applied: 0.5
# auc synth: 0.53727104 and 0.019087592165970033
# auc link: 0.9996961876940427 and 0.00033626859719634
# condition: -1.999111505997343e-07 and 3.5563769100454148e-06
# True FDP: 0.13603662021007953 and 0.006160600197731805
# bias our FDP: -0.0012376461873575759 and 0.023035313754050855
# bias other FDP: 0.018379476878084923 and 0.011357066559235334
